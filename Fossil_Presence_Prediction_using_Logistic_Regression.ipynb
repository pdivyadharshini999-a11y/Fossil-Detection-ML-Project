# %%
import pandas as pd
data = pd.read_csv("fossil_data.csv")
print(data)
# Out:
#     Depth  RockHardness  SoilMoisture  MineralContent RegionType  FossilFound
# 0     300             8            20              90     Desert            1
# 1     280             7            25              85     Desert            1
# 2     260             7            30              80     Desert            1
# 3     240             6            35              78     Desert            1
# 4     220             6            40              75     Desert            1
# 5     200             5            45              70     Desert            1
# 6     180             5            50              65     Forest            0
# 7     160             4            55              60     Forest            0
# 8     140             4            60              55     Forest            0
# 9     120             3            65              50     Forest            0
# 10    100             3            70              45     Forest            0
# 11     80             2            75              40     Forest            0
# 12    310             9            18              92     Desert            1
# 13    270             8            28              88     Desert            1
# 14    230             6            38              76     Desert            1
# 15    190             5            48              68     Forest            0
# 16    150             4            58              58     Forest            0
# 17    110             3            68              48     Forest            0
# 18     90             2            73              42     Forest            0
# 19    320             9            15              95     Desert            1

# %%
print(data.head(10))
print(data.tail(11))
print(data.info())
# Out:
#    Depth  RockHardness  SoilMoisture  MineralContent RegionType  FossilFound
# 0    300             8            20              90     Desert            1
# 1    280             7            25              85     Desert            1
# 2    260             7            30              80     Desert            1
# 3    240             6            35              78     Desert            1
# 4    220             6            40              75     Desert            1
# 5    200             5            45              70     Desert            1
# 6    180             5            50              65     Forest            0
# 7    160             4            55              60     Forest            0
# 8    140             4            60              55     Forest            0
# 9    120             3            65              50     Forest            0
#     Depth  RockHardness  SoilMoisture  MineralContent RegionType  FossilFound
# 9     120             3            65              50     Forest            0
# 10    100             3            70              45     Forest            0
# 11     80             2            75              40     Forest            0
# 12    310             9            18              92     Desert            1
# 13    270             8            28              88     Desert            1
# 14    230             6            38              76     Desert            1
# 15    190             5            48              68     Forest            0
# 16    150             4            58              58     Forest            0
# 17    110             3            68              48     Forest            0
# 18     90             2            73              42     Forest            0
# 19    320             9            15              95     Desert            1
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Depth           20 non-null     int64
#  1   RockHardness    20 non-null     int64
#  2   SoilMoisture    20 non-null     int64
#  3   MineralContent  20 non-null     int64
#  4   RegionType      20 non-null     object
#  5   FossilFound     20 non-null     int64
# dtypes: int64(5), object(1)
# memory usage: 1.1+ KB
# None

# %%
print(data.isnull().sum())
# Out:
# Depth             0
# RockHardness      0
# SoilMoisture      0
# MineralContent    0
# RegionType        0
# FossilFound       0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
data["RegionType"] = le.fit_transform(data["RegionType"])

# %%
x = data.drop(["FossilFound"],axis=1)
y = data["FossilFound"]

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(
    x,y,test_size=0.2,random_state=20
)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression

log = LogisticRegression()

print(log)

training = log.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = log.predict(x_test)
print("Prediction :",y_pred)
# Out:
# Prediction : [0 1 0 1]

# %%
from sklearn.metrics import accuracy_score

acc = accuracy_score(y_test,y_pred)
print("Accuracy score :",acc)
# Out:
# Accuracy score : 1.0

# %%
print("Actual data :",y_test)
print("Predicted data :",y_pred)
# Out:
# Actual data : 16    0
# 13    1
# 10    0
# 4     1
# Name: FossilFound, dtype: int64
# Predicted data : [0 1 0 1]
